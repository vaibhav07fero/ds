# %% [markdown]
# <a href="https://colab.research.google.com/github/vaibhav07fero/ds/blob/main/pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
s=pd.Series([1,3,5,np.nan,6,8])

# %%
s
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
dates=pd.date_range("20230101", periods=6)

# %%
dates
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df=pd.DataFrame(np.random.randn(6,4),index=dates,columns=list("ABCD"))

# %%
df
# Out:
#                    A         B         C         D
# 2023-01-01  1.049195 -1.112198 -2.311012 -1.112790
# 2023-01-02 -1.092856 -0.740389 -1.288916 -1.454523
# 2023-01-03 -1.537542  0.954655 -0.709293  0.251980
# 2023-01-04  0.971958  1.696206 -0.412857  0.450884
# 2023-01-05  2.505372 -0.942022  0.221805  0.760281
# 2023-01-06 -0.659323  0.962030  0.420575 -1.082122

# %%
df2=pd.DataFrame({"A":1.0,"B":pd.Timestamp('20230102'),
                  "C":pd.Series(1, index=list(range(4)), dtype="float32"), "D": np.array([3] * 4, dtype="int32"),
                  "E": pd.Categorical(["test", "train", "test", "train"]),"F": "foo",})

# %%
df2
# Out:
#      A          B    C  D      E    F
# 0  1.0 2023-01-02  1.0  3   test  foo
# 1  1.0 2023-01-02  1.0  3  train  foo
# 2  1.0 2023-01-02  1.0  3   test  foo
# 3  1.0 2023-01-02  1.0  3  train  foo

# %%
df2.dtypes
# Out:
# A           float64
# B    datetime64[ns]
# C           float32
# D             int32
# E          category
# F            object
# dtype: object

# %%
df.head()
# Out:
#                    A         B         C         D
# 2023-01-01  1.049195 -1.112198 -2.311012 -1.112790
# 2023-01-02 -1.092856 -0.740389 -1.288916 -1.454523
# 2023-01-03 -1.537542  0.954655 -0.709293  0.251980
# 2023-01-04  0.971958  1.696206 -0.412857  0.450884
# 2023-01-05  2.505372 -0.942022  0.221805  0.760281

# %%
df.tail(3)
# Out:
#                    A         B         C         D
# 2023-01-04  0.971958  1.696206 -0.412857  0.450884
# 2023-01-05  2.505372 -0.942022  0.221805  0.760281
# 2023-01-06 -0.659323  0.962030  0.420575 -1.082122

# %%
df.index
# Out:
# DatetimeIndex(['2023-01-01', '2023-01-02', '2023-01-03', '2023-01-04',
#                '2023-01-05', '2023-01-06'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.columns
# Out:
# Index(['A', 'B', 'C', 'D'], dtype='object')

# %%
# DataFrame.to_numpy() gives a NumPy representation of the underlying data.
df.to_numpy()
# Out:
# array([[ 1.04919481, -1.11219847, -2.31101216, -1.11279018],
#        [-1.09285644, -0.74038911, -1.28891648, -1.45452267],
#        [-1.53754203,  0.95465465, -0.70929348,  0.2519802 ],
#        [ 0.97195754,  1.69620559, -0.41285678,  0.45088396],
#        [ 2.50537223, -0.94202245,  0.22180509,  0.76028094],
#        [-0.65932323,  0.96203048,  0.42057498, -1.08212231]])

# %%
df2.to_numpy()
# Out:
# array([[1.0, Timestamp('2023-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2023-01-02 00:00:00'), 1.0, 3, 'train', 'foo'],
#        [1.0, Timestamp('2023-01-02 00:00:00'), 1.0, 3, 'test', 'foo'],
#        [1.0, Timestamp('2023-01-02 00:00:00'), 1.0, 3, 'train', 'foo']],
#       dtype=object)

# %%
# shows a quick statistic summary of data:
df.describe()
# Out:
#               A         B         C         D
# count  6.000000  6.000000  6.000000  6.000000
# mean   0.206134  0.136380 -0.679950 -0.364382
# std    1.553096  1.206230  1.012692  0.956358
# min   -1.537542 -1.112198 -2.311012 -1.454523
# 25%   -0.984473 -0.891614 -1.144011 -1.105123
# 50%    0.156317  0.107133 -0.561075 -0.415071
# 75%    1.029885  0.960187  0.063140  0.401158
# max    2.505372  1.696206  0.420575  0.760281

# %%
# Transposing data:
df.T
# Out:
#    2023-01-01  2023-01-02  2023-01-03  2023-01-04  2023-01-05  2023-01-06
# A    1.049195   -1.092856   -1.537542    0.971958    2.505372   -0.659323
# B   -1.112198   -0.740389    0.954655    1.696206   -0.942022    0.962030
# C   -2.311012   -1.288916   -0.709293   -0.412857    0.221805    0.420575
# D   -1.112790   -1.454523    0.251980    0.450884    0.760281   -1.082122

# %%
df.sort_index(axis=1,ascending=False)
# Out:
#                    D         C         B         A
# 2023-01-01 -1.112790 -2.311012 -1.112198  1.049195
# 2023-01-02 -1.454523 -1.288916 -0.740389 -1.092856
# 2023-01-03  0.251980 -0.709293  0.954655 -1.537542
# 2023-01-04  0.450884 -0.412857  1.696206  0.971958
# 2023-01-05  0.760281  0.221805 -0.942022  2.505372
# 2023-01-06 -1.082122  0.420575  0.962030 -0.659323

# %%
df.sort_values(by="B")
# Out:
#                    A         B         C         D
# 2023-01-01  1.049195 -1.112198 -2.311012 -1.112790
# 2023-01-05  2.505372 -0.942022  0.221805  0.760281
# 2023-01-02 -1.092856 -0.740389 -1.288916 -1.454523
# 2023-01-03 -1.537542  0.954655 -0.709293  0.251980
# 2023-01-06 -0.659323  0.962030  0.420575 -1.082122
# 2023-01-04  0.971958  1.696206 -0.412857  0.450884

# %%
df.loc[dates[0]]
# Out:
# A    1.049195
# B   -1.112198
# C   -2.311012
# D   -1.112790
# Name: 2023-01-01 00:00:00, dtype: float64

# %%
df.loc[:,["A","B"]]
# Out:
#                    A         B
# 2023-01-01  1.049195 -1.112198
# 2023-01-02 -1.092856 -0.740389
# 2023-01-03 -1.537542  0.954655
# 2023-01-04  0.971958  1.696206
# 2023-01-05  2.505372 -0.942022
# 2023-01-06 -0.659323  0.962030

# %%
# Showing label slicing, both endpoints are included:
df.loc["20230102":"20230104", ["A", "B"]]
# Out:
#                    A         B
# 2023-01-02 -1.092856 -0.740389
# 2023-01-03 -1.537542  0.954655
# 2023-01-04  0.971958  1.696206

# %%
df.loc["20230102", ["A", "B"]]
# Out:
# A   -1.092856
# B   -0.740389
# Name: 2023-01-02 00:00:00, dtype: float64

# %%
df.loc[dates[0], "A"]
# Out:
# 1.0491948142836482

# %%
df.at[dates[0], "A"]
# Out:
# 1.0491948142836482

# %%
df
# Out:
#                    A         B         C         D
# 2023-01-01  1.049195 -1.112198 -2.311012 -1.112790
# 2023-01-02 -1.092856 -0.740389 -1.288916 -1.454523
# 2023-01-03 -1.537542  0.954655 -0.709293  0.251980
# 2023-01-04  0.971958  1.696206 -0.412857  0.450884
# 2023-01-05  2.505372 -0.942022  0.221805  0.760281
# 2023-01-06 -0.659323  0.962030  0.420575 -1.082122

# %%
# Selection by position
df.iloc[3]
# Out:
# A    0.971958
# B    1.696206
# C   -0.412857
# D    0.450884
# Name: 2023-01-04 00:00:00, dtype: float64

# %%
df.iloc[3:5, 0:2]
# Out:
#                    A         B
# 2023-01-04  0.971958  1.696206
# 2023-01-05  2.505372 -0.942022

# %%
df.iloc[[1, 2, 4], [0, 2]]
# Out:
#                    A         C
# 2023-01-02 -1.092856 -1.288916
# 2023-01-03 -1.537542 -0.709293
# 2023-01-05  2.505372  0.221805

# %%
df.iloc[1:3, :]
# Out:
#                    A         B         C         D
# 2023-01-02 -1.092856 -0.740389 -1.288916 -1.454523
# 2023-01-03 -1.537542  0.954655 -0.709293  0.251980

# %%
df.iloc[:, 1:3]
# Out:
#                    B         C
# 2023-01-01 -1.112198 -2.311012
# 2023-01-02 -0.740389 -1.288916
# 2023-01-03  0.954655 -0.709293
# 2023-01-04  1.696206 -0.412857
# 2023-01-05 -0.942022  0.221805
# 2023-01-06  0.962030  0.420575

# %%
df.iloc[1, 1]
# Out:
# -0.7403891106579452

# %%
df.iat[1, 1]
# Out:
# -0.7403891106579452

# %%
# Boolean indexing
df[df["A"] > 0]
# Out:
#                    A         B         C         D
# 2023-01-01  1.049195 -1.112198 -2.311012 -1.112790
# 2023-01-04  0.971958  1.696206 -0.412857  0.450884
# 2023-01-05  2.505372 -0.942022  0.221805  0.760281

# %%
df[df>0]
# Out:
#                    A         B         C         D
# 2023-01-01  1.049195       NaN       NaN       NaN
# 2023-01-02       NaN       NaN       NaN       NaN
# 2023-01-03       NaN  0.954655       NaN  0.251980
# 2023-01-04  0.971958  1.696206       NaN  0.450884
# 2023-01-05  2.505372       NaN  0.221805  0.760281
# 2023-01-06       NaN  0.962030  0.420575       NaN

# %%
df2=df.copy()

# %%
df2["E"]=["one","one","two","three","four","three"]

# %%
df2
# Out:
#                    A         B         C         D      E
# 2023-01-01  1.049195 -1.112198 -2.311012 -1.112790    one
# 2023-01-02 -1.092856 -0.740389 -1.288916 -1.454523    one
# 2023-01-03 -1.537542  0.954655 -0.709293  0.251980    two
# 2023-01-04  0.971958  1.696206 -0.412857  0.450884  three
# 2023-01-05  2.505372 -0.942022  0.221805  0.760281   four
# 2023-01-06 -0.659323  0.962030  0.420575 -1.082122  three

# %%
df2[df2["E"].isin(["two",'four'])]
# Out:
#                    A         B         C         D     E
# 2023-01-03 -1.537542  0.954655 -0.709293  0.251980   two
# 2023-01-05  2.505372 -0.942022  0.221805  0.760281  four

# %%
# Setting values by label
df.at[dates[0],"A"]=0

# %%
# Setting values by position
df.iat[0,1]=0

# %%
# Setting by assigning with a NumPy array:
df.loc[:, "D"] = np.array([5] * len(df))
# Out:
# <ipython-input-44-5b6c060915b1>:2: DeprecationWarning: In a future version, `df.iloc[:, i] = newvals` will attempt to set the values inplace instead of always setting a new array. To retain the old behavior, use either `df[df.columns[i]] = newvals` or, if columns are non-unique, `df.isetitem(i, newvals)`
#   df.loc[:, "D"] = np.array([5] * len(df))

# %%
# A where operation with setting:
df2 = df.copy()

# %%
df2[df2>0]=-df2

# %%
df2
# Out:
#                    A         B         C  D
# 2023-01-01  0.000000  0.000000 -2.311012 -5
# 2023-01-02 -1.092856 -0.740389 -1.288916 -5
# 2023-01-03 -1.537542 -0.954655 -0.709293 -5
# 2023-01-04 -0.971958 -1.696206 -0.412857 -5
# 2023-01-05 -2.505372 -0.942022 -0.221805 -5
# 2023-01-06 -0.659323 -0.962030 -0.420575 -5

# %%
# Missing data
# Reindexing allows you to change/add/delete the index on a specified axis. This returns a copy of the data:
df1=df.reindex(index=dates[0:4],columns=list(df.columns)+["E"])

# %%
df1.loc[dates[0]:dates[1],"E"]=1

# %%
df1.dropna(how="any")
# Out:
#                    A         B         C  D    E
# 2023-01-01  0.000000  0.000000 -2.311012  5  1.0
# 2023-01-02 -1.092856 -0.740389 -1.288916  5  1.0

# %%
df1
# Out:
#                    A         B         C  D    E
# 2023-01-01  0.000000  0.000000 -2.311012  5  1.0
# 2023-01-02 -1.092856 -0.740389 -1.288916  5  1.0
# 2023-01-03 -1.537542  0.954655 -0.709293  5  NaN
# 2023-01-04  0.971958  1.696206 -0.412857  5  NaN

# %%
df1.fillna(value=5)
# Out:
#                    A         B         C  D    E
# 2023-01-01  0.000000  0.000000 -2.311012  5  1.0
# 2023-01-02 -1.092856 -0.740389 -1.288916  5  1.0
# 2023-01-03 -1.537542  0.954655 -0.709293  5  5.0
# 2023-01-04  0.971958  1.696206 -0.412857  5  5.0

# %%
pd.isna(df1)
# Out:
#                 A      B      C      D      E
# 2023-01-01  False  False  False  False  False
# 2023-01-02  False  False  False  False  False
# 2023-01-03  False  False  False  False   True
# 2023-01-04  False  False  False  False   True

# %%
# Operations
df.mean()
# Out:
# A    0.031268
# B    0.321747
# C   -0.679950
# D    5.000000
# dtype: float64

# %%
# Same operation on the other axis:
df.mean(1)
# Out:
# 2023-01-01    0.672247
# 2023-01-02    0.469459
# 2023-01-03    0.926955
# 2023-01-04    1.813827
# 2023-01-05    1.696289
# 2023-01-06    1.430821
# Freq: D, dtype: float64

# %%
s = pd.Series([1, 3, 5, np.nan, 6, 8], index=dates).shift(2)

# %%
s
# Out:
# 2023-01-01    NaN
# 2023-01-02    NaN
# 2023-01-03    1.0
# 2023-01-04    3.0
# 2023-01-05    5.0
# 2023-01-06    NaN
# Freq: D, dtype: float64

# %%
df.sub(s, axis="index")
# Out:
#                    A         B         C    D
# 2023-01-01       NaN       NaN       NaN  NaN
# 2023-01-02       NaN       NaN       NaN  NaN
# 2023-01-03 -2.537542 -0.045345 -1.709293  4.0
# 2023-01-04 -2.028042 -1.303794 -3.412857  2.0
# 2023-01-05 -2.494628 -5.942022 -4.778195  0.0
# 2023-01-06       NaN       NaN       NaN  NaN

# %%
# DataFrame.apply() applies a user defined function to the data:
df.apply(np.cumsum)
# Out:
#                    A         B         C   D
# 2023-01-01  0.000000  0.000000 -2.311012   5
# 2023-01-02 -1.092856 -0.740389 -3.599929  10
# 2023-01-03 -2.630398  0.214266 -4.309222  15
# 2023-01-04 -1.658441  1.910471 -4.722079  20
# 2023-01-05  0.846931  0.968449 -4.500274  25
# 2023-01-06  0.187608  1.930479 -4.079699  30

# %%
df.apply(lambda x: x.max() - x.min())
# Out:
# A    4.042914
# B    2.638228
# C    2.731587
# D    0.000000
# dtype: float64

# %%
# Histogramming
s = pd.Series(np.random.randint(0, 7, size=10))

# %%
s
# Out:
# 0    1
# 1    0
# 2    6
# 3    3
# 4    3
# 5    4
# 6    0
# 7    2
# 8    3
# 9    3
# dtype: int64

# %%
s.value_counts()
# Out:
# 3    4
# 0    2
# 1    1
# 6    1
# 4    1
# 2    1
# dtype: int64

# %%
# String Methods
s = pd.Series(["A", "B", "C", "Aaba", "Baca", np.nan, "CABA", "dog", "cat"])

# %%
s.str.lower()
# Out:
# 0       a
# 1       b
# 2       c
# 3    aaba
# 4    baca
# 5     NaN
# 6    caba
# 7     dog
# 8     cat
# dtype: object

# %%
s
# Out:
# 0       A
# 1       B
# 2       C
# 3    Aaba
# 4    Baca
# 5     NaN
# 6    CABA
# 7     dog
# 8     cat
# dtype: object

# %%
# Merge
df = pd.DataFrame(np.random.randn(10, 4))

# %%
df
# Out:
#           0         1         2         3
# 0  0.867764  0.999113  0.204166  0.946598
# 1 -1.129602  0.155079  0.216045  0.707555
# 2 -0.036835  0.321116  0.476135 -0.778446
# 3 -1.573528 -0.204225  2.798733  1.427535
# 4  1.649881 -1.382241 -1.279660  0.081304
# 5 -0.801409  0.370446  1.096998  0.995372
# 6 -0.851882  0.550899  0.916749  1.555243
# 7  0.104550 -0.833810 -0.287310  0.128783
# 8  0.916334 -0.908662  0.453117 -1.206905
# 9 -1.011910 -0.391300  0.226516  0.700702

# %%
# break it into pieces
pieces = [df[:3], df[3:7], df[7:]]

# %%
pieces
# Out:
# [          0         1         2         3
#  0  0.867764  0.999113  0.204166  0.946598
#  1 -1.129602  0.155079  0.216045  0.707555
#  2 -0.036835  0.321116  0.476135 -0.778446,
#            0         1         2         3
#  3 -1.573528 -0.204225  2.798733  1.427535
#  4  1.649881 -1.382241 -1.279660  0.081304
#  5 -0.801409  0.370446  1.096998  0.995372
#  6 -0.851882  0.550899  0.916749  1.555243,
#            0         1         2         3
#  7  0.104550 -0.833810 -0.287310  0.128783
#  8  0.916334 -0.908662  0.453117 -1.206905
#  9 -1.011910 -0.391300  0.226516  0.700702]

# %%
pd.concat(pieces)
# Out:
#           0         1         2         3
# 0  0.867764  0.999113  0.204166  0.946598
# 1 -1.129602  0.155079  0.216045  0.707555
# 2 -0.036835  0.321116  0.476135 -0.778446
# 3 -1.573528 -0.204225  2.798733  1.427535
# 4  1.649881 -1.382241 -1.279660  0.081304
# 5 -0.801409  0.370446  1.096998  0.995372
# 6 -0.851882  0.550899  0.916749  1.555243
# 7  0.104550 -0.833810 -0.287310  0.128783
# 8  0.916334 -0.908662  0.453117 -1.206905
# 9 -1.011910 -0.391300  0.226516  0.700702

# %%
# Join
left = pd.DataFrame({"key": ["foo", "foo"], "lval": [1, 2]})

# %%
right = pd.DataFrame({"key": ["foo", "foo"], "rval": [4, 5]})

# %%
left
# Out:
#    key  lval
# 0  foo     1
# 1  foo     2

# %%
right
# Out:
#    key  rval
# 0  foo     4
# 1  foo     5

# %%
pd.merge(left, right, on="key")
# Out:
#    key  lval  rval
# 0  foo     1     4
# 1  foo     1     5
# 2  foo     2     4
# 3  foo     2     5

# %%
#GROUPING
# By “group by” we are referring to a process involving one or more of the following steps:

# Splitting the data into groups based on some criteria
# Applying a function to each group independently
# Combining the results into a data structure

# %%
df = pd.DataFrame(
    {
        "A": ["foo", "bar", "foo", "bar", "foo", "bar", "foo", "foo"],
        "B": ["one", "one", "two", "three", "two", "two", "one", "three"],
        "C": np.random.randn(8),
        "D": np.random.randn(8),
    }
)

# %%
df
# Out:
#      A      B         C         D
# 0  foo    one  2.876078  0.382073
# 1  bar    one -0.037010  0.737328
# 2  foo    two  0.648642  0.644813
# 3  bar  three  0.204870  0.086445
# 4  foo    two  0.530426  0.380798
# 5  bar    two -0.326825  2.181320
# 6  foo    one  0.695504 -0.032119
# 7  foo  three -0.806592 -0.009753

# %%
df.groupby("A")[["C", "D"]].sum()
# Out:
#             C         D
# A
# bar -0.158966  3.005093
# foo  3.944058  1.365811

# %%
df.groupby(["A", "B"]).sum()
# Out:
#                   C         D
# A   B
# bar one   -0.037010  0.737328
#     three  0.204870  0.086445
#     two   -0.326825  2.181320
# foo one    3.571582  0.349954
#     three -0.806592 -0.009753
#     two    1.179068  1.025611

# %%
# Reshaping
tuples = list(
    zip(
        ["bar", "bar", "baz", "baz", "foo", "foo", "qux", "qux"],
        ["one", "two", "one", "two", "one", "two", "one", "two"],
    )
)

# %%
tuples
# Out:
# [('bar', 'one'),
#  ('bar', 'two'),
#  ('baz', 'one'),
#  ('baz', 'two'),
#  ('foo', 'one'),
#  ('foo', 'two'),
#  ('qux', 'one'),
#  ('qux', 'two')]

# %%
index = pd.MultiIndex.from_tuples(tuples, names=["first", "second"])

# %%
df = pd.DataFrame(np.random.randn(8, 2), index=index, columns=["A", "B"])

# %%
df2 = df[:4]

# %%
df2
# Out:
#                      A         B
# first second
# bar   one    -0.999372  0.935888
#       two     0.899997  1.616241
# baz   one     1.651702  1.320707
#       two     1.075765  0.709450

# %%
stacked = df2.stack()

# %%
stacked
# Out:
# first  second
# bar    one     A   -0.999372
#                B    0.935888
#        two     A    0.899997
#                B    1.616241
# baz    one     A    1.651702
#                B    1.320707
#        two     A    1.075765
#                B    0.709450
# dtype: float64

# %%
# Time series
rng = pd.date_range("1/1/2023", periods=100, freq="S")

# %%
rng
# Out:
# DatetimeIndex(['2023-01-01 00:00:00', '2023-01-01 00:00:01',
#                '2023-01-01 00:00:02', '2023-01-01 00:00:03',
#                '2023-01-01 00:00:04', '2023-01-01 00:00:05',
#                '2023-01-01 00:00:06', '2023-01-01 00:00:07',
#                '2023-01-01 00:00:08', '2023-01-01 00:00:09',
#                '2023-01-01 00:00:10', '2023-01-01 00:00:11',
#                '2023-01-01 00:00:12', '2023-01-01 00:00:13',
#                '2023-01-01 00:00:14', '2023-01-01 00:00:15',
#                '2023-01-01 00:00:16', '2023-01-01 00:00:17',
#                '2023-01-01 00:00:18', '2023-01-01 00:00:19',
#                '2023-01-01 00:00:20', '2023-01-01 00:00:21',
#                '2023-01-01 00:00:22', '2023-01-01 00:00:23',
#                '2023-01-01 00:00:24', '2023-01-01 00:00:25',
#                '2023-01-01 00:00:26', '2023-01-01 00:00:27',
#                '2023-01-01 00:00:28', '2023-01-01 00:00:29',
#                '2023-01-01 00:00:30', '2023-01-01 00:00:31',
#                '2023-01-01 00:00:32', '2023-01-01 00:00:33',
#                '2023-01-01 00:00:34', '2023-01-01 00:00:35',
#                '2023-01-01 00:00:36', '2023-01-01 00:00:37',
#                '2023-01-01 00:00:38', '2023-01-01 00:00:39',
#                '2023-01-01 00:00:40', '2023-01-01 00:00:41',
#                '2023-01-01 00:00:42', '2023-01-01 00:00:43',
#                '2023-01-01 00:00:44', '2023-01-01 00:00:45',
#                '2023-01-01 00:00:46', '2023-01-01 00:00:47',
#                '2023-01-01 00:00:48', '2023-01-01 00:00:49',
#                '2023-01-01 00:00:50', '2023-01-01 00:00:51',
#                '2023-01-01 00:00:52', '2023-01-01 00:00:53',
#                '2023-01-01 00:00:54', '2023-01-01 00:00:55',
#                '2023-01-01 00:00:56', '2023-01-01 00:00:57',
#                '2023-01-01 00:00:58', '2023-01-01 00:00:59',
#                '2023-01-01 00:01:00', '2023-01-01 00:01:01',
#                '2023-01-01 00:01:02', '2023-01-01 00:01:03',
#                '2023-01-01 00:01:04', '2023-01-01 00:01:05',
#                '2023-01-01 00:01:06', '2023-01-01 00:01:07',
#                '2023-01-01 00:01:08', '2023-01-01 00:01:09',
#                '2023-01-01 00:01:10', '2023-01-01 00:01:11',
#                '2023-01-01 00:01:12', '2023-01-01 00:01:13',
#                '2023-01-01 00:01:14', '2023-01-01 00:01:15',
#                '2023-01-01 00:01:16', '2023-01-01 00:01:17',
#                '2023-01-01 00:01:18', '2023-01-01 00:01:19',
#                '2023-01-01 00:01:20', '2023-01-01 00:01:21',
#                '2023-01-01 00:01:22', '2023-01-01 00:01:23',
#                '2023-01-01 00:01:24', '2023-01-01 00:01:25',
#                '2023-01-01 00:01:26', '2023-01-01 00:01:27',
#                '2023-01-01 00:01:28', '2023-01-01 00:01:29',
#                '2023-01-01 00:01:30', '2023-01-01 00:01:31',
#                '2023-01-01 00:01:32', '2023-01-01 00:01:33',
#                '2023-01-01 00:01:34', '2023-01-01 00:01:35',
#                '2023-01-01 00:01:36', '2023-01-01 00:01:37',
#                '2023-01-01 00:01:38', '2023-01-01 00:01:39'],
#               dtype='datetime64[ns]', freq='S')

# %%
ts = pd.Series(np.random.randint(0, 500, len(rng)), index=rng)

# %%
ts
# Out:
# 2023-01-01 00:00:00      5
# 2023-01-01 00:00:01    105
# 2023-01-01 00:00:02     61
# 2023-01-01 00:00:03    216
# 2023-01-01 00:00:04    421
#                       ...
# 2023-01-01 00:01:35    346
# 2023-01-01 00:01:36    333
# 2023-01-01 00:01:37     99
# 2023-01-01 00:01:38    112
# 2023-01-01 00:01:39    178
# Freq: S, Length: 100, dtype: int64

# %%
ts.resample("5Min").sum()
# Out:
# 2023-01-01    23581
# Freq: 5T, dtype: int64

# %%
rng = pd.date_range("3/6/2023 00:00", periods=5, freq="D")

# %%
ts = pd.Series(np.random.randn(len(rng)), rng)

# %%
ts
# Out:
# 2023-03-06   -0.411000
# 2023-03-07    0.055221
# 2023-03-08   -0.408949
# 2023-03-09    0.816813
# 2023-03-10   -0.671878
# Freq: D, dtype: float64

# %%
ts_utc = ts.tz_localize("UTC")

# %%
ts_utc
# Out:
# 2023-03-06 00:00:00+00:00   -0.411000
# 2023-03-07 00:00:00+00:00    0.055221
# 2023-03-08 00:00:00+00:00   -0.408949
# 2023-03-09 00:00:00+00:00    0.816813
# 2023-03-10 00:00:00+00:00   -0.671878
# Freq: D, dtype: float64

# %%
ts_utc.tz_convert("US/Eastern")
# Out:
# 2023-03-05 19:00:00-05:00   -0.411000
# 2023-03-06 19:00:00-05:00    0.055221
# 2023-03-07 19:00:00-05:00   -0.408949
# 2023-03-08 19:00:00-05:00    0.816813
# 2023-03-09 19:00:00-05:00   -0.671878
# Freq: D, dtype: float64

# %%
ps = ts.to_period()

# %%
ps.to_timestamp()
# Out:
# 2023-03-06   -0.411000
# 2023-03-07    0.055221
# 2023-03-08   -0.408949
# 2023-03-09    0.816813
# 2023-03-10   -0.671878
# Freq: D, dtype: float64

# %%
# Categoricals
df = pd.DataFrame(
    {"id": [1, 2, 3, 4, 5, 6], "raw_grade": ["a", "b", "b", "a", "a", "e"]}
)

# %%
df
# Out:
#    id raw_grade
# 0   1         a
# 1   2         b
# 2   3         b
# 3   4         a
# 4   5         a
# 5   6         e

# %%
df["grade"] = df["raw_grade"].astype("category")

# %%
df["grade"]
# Out:
# 0    a
# 1    b
# 2    b
# 3    a
# 4    a
# 5    e
# Name: grade, dtype: category
# Categories (3, object): ['a', 'b', 'e']

# %%
new_categories = ["very good", "good", "very bad"]

# %%
df["grade"] = df["grade"].cat.rename_categories(new_categories)

# %%
df["grade"] = df["grade"].cat.set_categories(
    ["very bad", "bad", "medium", "good", "very good"]
)

# %%
df
# Out:
#    id raw_grade      grade
# 0   1         a  very good
# 1   2         b       good
# 2   3         b       good
# 3   4         a  very good
# 4   5         a  very good
# 5   6         e   very bad

# %%
df.sort_values(by="grade")
# Out:
#    id raw_grade      grade
# 5   6         e   very bad
# 1   2         b       good
# 2   3         b       good
# 0   1         a  very good
# 3   4         a  very good
# 4   5         a  very good

# %%
df.groupby("grade").size()
# Out:
# grade
# very bad     1
# bad          0
# medium       0
# good         2
# very good    3
# dtype: int64

# %%
# Plotting
import matplotlib.pyplot as plt

# %%
# The plt.close method is used to close a figure window:
plt.close("all")

# %%
ts=pd.Series(np.random.randn(1000),index=pd.date_range('1/1/2023',periods=1000))

# %%
ts=ts.cumsum()

# %%
ts.plot()
# Out:
# <Axes: >

# %%
df = pd.DataFrame(
    np.random.randn(1000, 4), index=ts.index, columns=["A", "B", "C", "D"]
)

# %%
df=df.cumsum()

# %%
plt.figure();

# %%
df.plot()
# Out:
# <Axes: >

# %%
# Importing and exporting data
df.to_csv("foo.csv")

# %%
pd.read_csv("foo.csv")
# Out:
#      Unnamed: 0             A             B            C             D
# 0    2023-01-01     -1.407682     -0.582509     1.151979     -0.896266
# 1    2023-01-02     -3.911577     -1.614653     1.503698     -1.500019
# 2    2023-01-03     -5.049804     -1.830068     1.939645      0.050516
# 3    2023-01-04     -5.681414     -1.730474     2.330522      3.499312
# 4    2023-01-05     -4.726776     -2.552336     3.249246      8.750587
# ..          ...           ...           ...          ...           ...
# 995  2025-09-22  25641.543049  26431.422641  6494.506579  12439.431807
# 996  2025-09-23  25685.062488  26464.628543  6498.542125  12461.759733
# 997  2025-09-24  25729.222914  26495.354970  6501.887133  12482.858110
# 998  2025-09-25  25774.039592  26526.346321  6503.512238  12502.961099
# 999  2025-09-26  25819.700441  26556.762874  6505.546225  12523.508562
#
# [1000 rows x 5 columns]

# %%
# HDF5
df.to_hdf("foo.h5", "df")

# %%
pd.read_hdf("foo.h5", "df")
# Out:
#                        A             B            C             D
# 2023-01-01     -1.407682     -0.582509     1.151979     -0.896266
# 2023-01-02     -3.911577     -1.614653     1.503698     -1.500019
# 2023-01-03     -5.049804     -1.830068     1.939645      0.050516
# 2023-01-04     -5.681414     -1.730474     2.330522      3.499312
# 2023-01-05     -4.726776     -2.552336     3.249246      8.750587
# ...                  ...           ...          ...           ...
# 2025-09-22  25641.543049  26431.422641  6494.506579  12439.431807
# 2025-09-23  25685.062488  26464.628543  6498.542125  12461.759733
# 2025-09-24  25729.222914  26495.354970  6501.887133  12482.858110
# 2025-09-25  25774.039592  26526.346321  6503.512238  12502.961099
# 2025-09-26  25819.700441  26556.762874  6505.546225  12523.508562
#
# [1000 rows x 4 columns]

# %%
df.to_excel("foo.xlsx", sheet_name="Sheet1")

# %%
pd.read_excel("foo.xlsx", "Sheet1", index_col=None, na_values=["NA"])
# Out:
#     Unnamed: 0             A             B            C             D
# 0   2023-01-01     -1.407682     -0.582509     1.151979     -0.896266
# 1   2023-01-02     -3.911577     -1.614653     1.503698     -1.500019
# 2   2023-01-03     -5.049804     -1.830068     1.939645      0.050516
# 3   2023-01-04     -5.681414     -1.730474     2.330522      3.499312
# 4   2023-01-05     -4.726776     -2.552336     3.249246      8.750587
# ..         ...           ...           ...          ...           ...
# 995 2025-09-22  25641.543049  26431.422641  6494.506579  12439.431807
# 996 2025-09-23  25685.062488  26464.628543  6498.542125  12461.759733
# 997 2025-09-24  25729.222914  26495.354970  6501.887133  12482.858110
# 998 2025-09-25  25774.039592  26526.346321  6503.512238  12502.961099
# 999 2025-09-26  25819.700441  26556.762874  6505.546225  12523.508562
#
# [1000 rows x 5 columns]
